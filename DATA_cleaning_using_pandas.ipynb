# %%
import pandas as pd
import numpy as np

# %%
A=pd.read_csv("C:/Users/murkr/OneDrive/Desktop/RED_BUS/Bus_data.csv")
A
# Out:
#              busname                                bustype depature_time  \
# 0           FRESHBUS              Electric A/C Seater (2+2)         23:20
# 1           FRESHBUS              Electric A/C Seater (2+2)         16:00
# 2           FRESHBUS              Electric A/C Seater (2+2)         10:25
# 3         AdYolo Bus          Bharat Benz A/C Sleeper (2+1)         19:40
# 4           FRESHBUS              Electric A/C Seater (2+2)         11:20
# ...              ...                                    ...           ...
# 6102  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:20
# 6103  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6104  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
# 6105             NaN                                    NaN           NaN
# 6106             NaN                                    NaN           NaN
#
#      travel_time end_time star_rating     price      seat_available  \
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6107 entries, 0 to 6106
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   busname         6017 non-null   object
#  1   bustype         6001 non-null   object
#  2   depature_time   6017 non-null   object
#  3   travel_time     6017 non-null   object
#  4   end_time        6017 non-null   object
#  5   star_rating     6014 non-null   object
#  6   price           6013 non-null   object
#  7   seat_available  6008 non-null   object
#  8   routename       6107 non-null   object
#  9   routelink       4825 non-null   object
#  10  rouelink        1282 non-null   object
# dtypes: object(11)
# memory usage: 524.9+ KB

# %%
A["price"]=A["price"].str.replace("INR","")
A["price"]=A["price"].astype(float)
A
# Out:
#              busname                                bustype depature_time  \
# 0           FRESHBUS              Electric A/C Seater (2+2)         23:20
# 1           FRESHBUS              Electric A/C Seater (2+2)         16:00
# 2           FRESHBUS              Electric A/C Seater (2+2)         10:25
# 3         AdYolo Bus          Bharat Benz A/C Sleeper (2+1)         19:40
# 4           FRESHBUS              Electric A/C Seater (2+2)         11:20
# ...              ...                                    ...           ...
# 6102  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:20
# 6103  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6104  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
# 6105             NaN                                    NaN           NaN
# 6106             NaN                                    NaN           NaN
#
#      travel_time end_time star_rating   price      seat_available  \
# ...

# %%
A["star_rating"]=A["star_rating"].str.replace("New",'')
A["star_rating"]=pd.to_numeric(A["star_rating"],errors='coerce')

# %%
A["seat_available"]=A["seat_available"].str.replace("Seats available",'')
A["seat_available"]=A["seat_available"].str.replace("seat available",'')
A["seat_available"]=pd.to_numeric(A["seat_available"],errors='coerce')
A["seatavilable"]=A["seat_available"].fillna(0).astype(int)

# %%
CLEAN_DATA=A.dropna(subset=["busname"])
(CLEAN_DATA)
# Out:
#              busname                                bustype depature_time  \
# 0           FRESHBUS              Electric A/C Seater (2+2)         23:20
# 1           FRESHBUS              Electric A/C Seater (2+2)         16:00
# 2           FRESHBUS              Electric A/C Seater (2+2)         10:25
# 3         AdYolo Bus          Bharat Benz A/C Sleeper (2+1)         19:40
# 4           FRESHBUS              Electric A/C Seater (2+2)         11:20
# ...              ...                                    ...           ...
# 6098  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6099  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
# 6102  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:20
# 6103  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6104  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
#
#      travel_time end_time  star_rating   price  seat_available  \
# ...

# %%
CLEAN_DATA.to_csv("CLEAN_DATA.csv")
CLEAN_DATA
# Out:
#              busname                                bustype depature_time  \
# 0           FRESHBUS              Electric A/C Seater (2+2)         23:20
# 1           FRESHBUS              Electric A/C Seater (2+2)         16:00
# 2           FRESHBUS              Electric A/C Seater (2+2)         10:25
# 3         AdYolo Bus          Bharat Benz A/C Sleeper (2+1)         19:40
# 4           FRESHBUS              Electric A/C Seater (2+2)         11:20
# ...              ...                                    ...           ...
# 6098  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6099  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
# 6102  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:20
# 6103  Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)         22:00
# 6104  Laxmi holidays          Bharat Benz A/C Sleeper (2+1)         23:40
#
#      travel_time end_time  star_rating   price  seat_available  \
# ...
